# %% [markdown]
# # Applied Data Science 2 - Keras Assignment - 2023A
#
# In this assignment you will be building a script to classify images of animals. The assignment is broken up into sections and you need to complete each section successively. The sections are:
#
# 1. Data Processing
# 2. Model Definition
# 3. Model Training
# 4. Model Evaluation
#
# In addition to this coding exercise, you will also need to write a 1-2 page report analysing and critically evaluating you models results.

# %%
# Enter your module imports here, some modules are already provided
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Processing

# %%
# CodeGrade Tag DataProc

label_dict = {'cat' : 0,
              'dog' : 1,
              'wild' : 2}

# This function is provided to read in the image files from the folder on your
# Google Drive
def parse_image(filename):
  parts = tf.strings.split(filename, os.sep)
  label = parts[-2]
  label = tf.strings.to_number(label)

  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

img_loc = "/content/drive/MyDrive/Animals/"

train_list_ds = tf.data.Dataset.list_files(img_loc + "train/*/*")
valid_list_ds = tf.data.Dataset.list_files(img_loc + "val/*/*")

# %% [markdown]
# **Create a function called "img_process" converts the images to float32 datatype and resizes them to 64x64 pixels.**

# %%
# CodeGrade Tag Ex1a
### Write a function called img_process, which takes in the image and label as
### inputs, converts the data type of the image to tf.float32, resizes the
### image to (64,64), and finally returns the image and labels.

def img_process(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, (64, 64))
    return image, label

# %% [markdown]
# **Using the tf.data API, load in the training and validation data. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1b
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 128. Use techniques like caching and
### prefetching to efficiently load the data.

batch_size = 128

train_ds = (train_list_ds.map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE).batch(batch_size).cache().shuffle(buffer_size=1000).prefetch(buffer_size=tf.data.AUTOTUNE))

valid_ds = (valid_list_ds.map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE).batch(batch_size).cache().prefetch(buffer_size=tf.data.AUTOTUNE))

# %% [markdown]
# # Model Definition
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture show in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a SoftMax activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        1216
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 10)                5130
#
# =================================================================
# Total params: 363146 (1.39 MB)
# Trainable params: 363146 (1.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

# Define the input layer
input_layer = Input(shape=(64, 64, 3), name='Input')

# Convolutional block 1
conv0 = Conv2D(16, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv0')(input_layer)
conv1 = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv1')(conv0)
conv2 = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv2')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='Pool1')(conv2)

# Convolutional block 2
conv3 = Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv3')(pool1)
conv4 = Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv4')(conv3)
pool2 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='Pool2')(conv4)

# Convolutional block 3
conv5 = Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv5')(pool2)
conv6 = Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', name='Conv6')(conv5)

# Global Average Pooling
global_pool = GlobalAveragePooling2D(name='GlobalPool')(conv6)

# Fully Connected layers
fc1 = Dense(512, activation='relu', name='FC1')(global_pool)

# Output layer
output_layer = Dense(10, activation='softmax', name='Output')(fc1)

# Define the model
model = tf.keras.models.Model(inputs=input_layer, outputs=output_layer)

# %%
# CodeGrade Tag Ex2b
### Print the model summary and confirm is has the same architecture as the one
### provided.

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 64, 64, 16)        448
#
#  Conv1 (Conv2D)              (None, 64, 64, 32)        4640
#
#  Conv2 (Conv2D)              (None, 64, 64, 32)        9248
#
#  Pool1 (MaxPooling2D)        (None, 32, 32, 32)        0
#
#  Conv3 (Conv2D)              (None, 32, 32, 64)        18496
#
#  Conv4 (Conv2D)              (None, 32, 32, 64)        36928
#
#  Pool2 (MaxPooling2D)        (None, 16, 16, 64)        0
#
#  Conv5 (Conv2D)              (None, 16, 16, 128)       73856
#
#  Conv6 (Conv2D)              (None, 16, 16, 128)       147584
#
#  GlobalPool (GlobalAverageP  (None, 128)               0
#  ooling2D)
#
#  FC1 (Dense)                 (None, 512)               66048
#
#  Output (Dense)              (None, 10)                5130
#
# =================================================================
# Total params: 362378 (1.38 MB)
# Trainable params: 362378 (1.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Compile the model using the Adam Optimizer with a learning rate of ```5e-5```, ```sparse categorical crossentropy``` loss function, and ```accuracy``` metric.**

# %%
# CodeGrade Tag Ex2c

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-5),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Model Training
#
# **Create a Model Checkpoint Callback that saves the weights of the best performing epoch, based on the validation accuracy.**

# %%
# CodeGrade Tag Ex3a
### Create a ModelCheckpoint callback to store the bext weights from the model,
### based on the validation accuracy. Call this callback "checkpoint_callback"

checkpoint_filepath = '/content/checkpoint'
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath,
                                      save_best_only=True,
                                      monitor='val_accuracy',
                                      mode='max',
                                      verbose=1)

# %% [markdown]
# **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3b
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.01)

lr_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# **Train the model for 100 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3c
### Train the model for 100 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

history = model.fit(train_ds,
                    epochs=100,
                    validation_data=valid_ds,
                    callbacks=[checkpoint_callback, lr_callback])
# Out:
# Epoch 1/100
# 115/115 [==============================] - ETA: 0s - loss: 1.4956 - accuracy: 0.3422
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to /content/checkpoint
# 115/115 [==============================] - 860s 959ms/step - loss: 1.4956 - accuracy: 0.3422 - val_loss: 1.1036 - val_accuracy: 0.3333 - lr: 5.0000e-05
# Epoch 2/100
# 114/115 [============================>.] - ETA: 0s - loss: 1.0937 - accuracy: 0.3609
# Epoch 2: val_accuracy improved from 0.33333 to 0.35400, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 60ms/step - loss: 1.0936 - accuracy: 0.3607 - val_loss: 1.0853 - val_accuracy: 0.3540 - lr: 5.0000e-05
# Epoch 3/100
# 115/115 [==============================] - ETA: 0s - loss: 1.0516 - accuracy: 0.4393
# Epoch 3: val_accuracy improved from 0.35400 to 0.46467, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 55ms/step - loss: 1.0516 - accuracy: 0.4393 - val_loss: 1.0138 - val_accuracy: 0.4647 - lr: 5.0000e-05
# Epoch 4/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.9684 - accuracy: 0.5078
# Epoch 4: val_accuracy improved from 0.46467 to 0.58067, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 56ms/step - loss: 0.9686 - accuracy: 0.5073 - val_loss: 0.9082 - val_accuracy: 0.5807 - lr: 5.0000e-05
# Epoch 5/100
# 115/115 [==============================] - ETA: 0s - loss: 0.9020 - accuracy: 0.5371
# Epoch 5: val_accuracy did not improve from 0.58067
# 115/115 [==============================] - 5s 45ms/step - loss: 0.9020 - accuracy: 0.5371 - val_loss: 0.8711 - val_accuracy: 0.5427 - lr: 5.0000e-05
# Epoch 6/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.8517 - accuracy: 0.5725
# Epoch 6: val_accuracy did not improve from 0.58067
# 115/115 [==============================] - 5s 47ms/step - loss: 0.8515 - accuracy: 0.5733 - val_loss: 0.9227 - val_accuracy: 0.5807 - lr: 5.0000e-05
# Epoch 7/100
# 115/115 [==============================] - ETA: 0s - loss: 0.8386 - accuracy: 0.5803
# Epoch 7: val_accuracy improved from 0.58067 to 0.61400, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.8386 - accuracy: 0.5803 - val_loss: 0.8174 - val_accuracy: 0.6140 - lr: 5.0000e-05
# Epoch 8/100
# 115/115 [==============================] - ETA: 0s - loss: 0.8149 - accuracy: 0.6012
# Epoch 8: val_accuracy improved from 0.61400 to 0.62400, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 57ms/step - loss: 0.8149 - accuracy: 0.6012 - val_loss: 0.8003 - val_accuracy: 0.6240 - lr: 5.0000e-05
# Epoch 9/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7971 - accuracy: 0.6138
# Epoch 9: val_accuracy improved from 0.62400 to 0.65600, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 56ms/step - loss: 0.7971 - accuracy: 0.6138 - val_loss: 0.7893 - val_accuracy: 0.6560 - lr: 5.0000e-05
# Epoch 10/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.7860 - accuracy: 0.6237
# Epoch 10: val_accuracy improved from 0.65600 to 0.65733, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 58ms/step - loss: 0.7853 - accuracy: 0.6240 - val_loss: 0.7633 - val_accuracy: 0.6573 - lr: 5.0000e-05
# Epoch 11/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.6426
# Epoch 11: val_accuracy improved from 0.65733 to 0.68000, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 56ms/step - loss: 0.7637 - accuracy: 0.6426 - val_loss: 0.7437 - val_accuracy: 0.6800 - lr: 4.9502e-05
# Epoch 12/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7370 - accuracy: 0.6622
# Epoch 12: val_accuracy did not improve from 0.68000
# 115/115 [==============================] - 5s 46ms/step - loss: 0.7370 - accuracy: 0.6622 - val_loss: 0.7204 - val_accuracy: 0.6720 - lr: 4.9010e-05
# Epoch 13/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7254 - accuracy: 0.6719
# Epoch 13: val_accuracy improved from 0.68000 to 0.69333, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 59ms/step - loss: 0.7254 - accuracy: 0.6719 - val_loss: 0.7004 - val_accuracy: 0.6933 - lr: 4.8522e-05
# Epoch 14/100
# 115/115 [==============================] - ETA: 0s - loss: 0.7064 - accuracy: 0.6837
# Epoch 14: val_accuracy improved from 0.69333 to 0.71267, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.7064 - accuracy: 0.6837 - val_loss: 0.6944 - val_accuracy: 0.7127 - lr: 4.8039e-05
# Epoch 15/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6884 - accuracy: 0.6895
# Epoch 15: val_accuracy improved from 0.71267 to 0.72267, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.6884 - accuracy: 0.6895 - val_loss: 0.6667 - val_accuracy: 0.7227 - lr: 4.7561e-05
# Epoch 16/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6699 - accuracy: 0.7075
# Epoch 16: val_accuracy improved from 0.72267 to 0.72733, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.6699 - accuracy: 0.7075 - val_loss: 0.6540 - val_accuracy: 0.7273 - lr: 4.7088e-05
# Epoch 17/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6600 - accuracy: 0.7075
# Epoch 17: val_accuracy did not improve from 0.72733
# 115/115 [==============================] - 5s 46ms/step - loss: 0.6600 - accuracy: 0.7075 - val_loss: 0.6705 - val_accuracy: 0.7033 - lr: 4.6620e-05
# Epoch 18/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6450 - accuracy: 0.7206
# Epoch 18: val_accuracy did not improve from 0.72733
# 115/115 [==============================] - 5s 46ms/step - loss: 0.6450 - accuracy: 0.7206 - val_loss: 0.6296 - val_accuracy: 0.7207 - lr: 4.6156e-05
# Epoch 19/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6370 - accuracy: 0.7219
# Epoch 19: val_accuracy did not improve from 0.72733
# 115/115 [==============================] - 5s 46ms/step - loss: 0.6370 - accuracy: 0.7219 - val_loss: 0.6375 - val_accuracy: 0.7133 - lr: 4.5697e-05
# Epoch 20/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6302 - accuracy: 0.7273
# Epoch 20: val_accuracy improved from 0.72733 to 0.74800, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 57ms/step - loss: 0.6296 - accuracy: 0.7278 - val_loss: 0.6096 - val_accuracy: 0.7480 - lr: 4.5242e-05
# Epoch 21/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6213 - accuracy: 0.7321
# Epoch 21: val_accuracy improved from 0.74800 to 0.75267, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 60ms/step - loss: 0.6211 - accuracy: 0.7318 - val_loss: 0.5953 - val_accuracy: 0.7527 - lr: 4.4792e-05
# Epoch 22/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6069 - accuracy: 0.7382
# Epoch 22: val_accuracy improved from 0.75267 to 0.75800, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 56ms/step - loss: 0.6069 - accuracy: 0.7382 - val_loss: 0.5898 - val_accuracy: 0.7580 - lr: 4.4346e-05
# Epoch 23/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5938 - accuracy: 0.7454
# Epoch 23: val_accuracy improved from 0.75800 to 0.75867, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 60ms/step - loss: 0.5938 - accuracy: 0.7454 - val_loss: 0.5990 - val_accuracy: 0.7587 - lr: 4.3905e-05
# Epoch 24/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5970 - accuracy: 0.7399
# Epoch 24: val_accuracy improved from 0.75867 to 0.76267, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 55ms/step - loss: 0.5970 - accuracy: 0.7399 - val_loss: 0.5760 - val_accuracy: 0.7627 - lr: 4.3468e-05
# Epoch 25/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5774 - accuracy: 0.7535
# Epoch 25: val_accuracy improved from 0.76267 to 0.76933, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 64ms/step - loss: 0.5774 - accuracy: 0.7535 - val_loss: 0.5647 - val_accuracy: 0.7693 - lr: 4.3035e-05
# Epoch 26/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5787 - accuracy: 0.7541
# Epoch 26: val_accuracy did not improve from 0.76933
# 115/115 [==============================] - 5s 45ms/step - loss: 0.5787 - accuracy: 0.7541 - val_loss: 0.5781 - val_accuracy: 0.7673 - lr: 4.2607e-05
# Epoch 27/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5717 - accuracy: 0.7577
# Epoch 27: val_accuracy did not improve from 0.76933
# 115/115 [==============================] - 5s 46ms/step - loss: 0.5717 - accuracy: 0.7577 - val_loss: 0.5608 - val_accuracy: 0.7667 - lr: 4.2183e-05
# Epoch 28/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5645 - accuracy: 0.7635
# Epoch 28: val_accuracy improved from 0.76933 to 0.77333, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 56ms/step - loss: 0.5645 - accuracy: 0.7635 - val_loss: 0.5511 - val_accuracy: 0.7733 - lr: 4.1764e-05
# Epoch 29/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5563 - accuracy: 0.7661
# Epoch 29: val_accuracy did not improve from 0.77333
# 115/115 [==============================] - 5s 46ms/step - loss: 0.5563 - accuracy: 0.7661 - val_loss: 0.5770 - val_accuracy: 0.7687 - lr: 4.1348e-05
# Epoch 30/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5657 - accuracy: 0.7604
# Epoch 30: val_accuracy improved from 0.77333 to 0.79133, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 57ms/step - loss: 0.5659 - accuracy: 0.7602 - val_loss: 0.5376 - val_accuracy: 0.7913 - lr: 4.0937e-05
# Epoch 31/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5525 - accuracy: 0.7712
# Epoch 31: val_accuracy did not improve from 0.79133
# 115/115 [==============================] - 5s 46ms/step - loss: 0.5530 - accuracy: 0.7708 - val_loss: 0.5692 - val_accuracy: 0.7600 - lr: 4.0529e-05
# Epoch 32/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5512 - accuracy: 0.7669
# Epoch 32: val_accuracy did not improve from 0.79133
# 115/115 [==============================] - 5s 46ms/step - loss: 0.5512 - accuracy: 0.7669 - val_loss: 0.5502 - val_accuracy: 0.7627 - lr: 4.0126e-05
# Epoch 33/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5452 - accuracy: 0.7713
# Epoch 33: val_accuracy did not improve from 0.79133
# 115/115 [==============================] - 5s 45ms/step - loss: 0.5452 - accuracy: 0.7713 - val_loss: 0.5537 - val_accuracy: 0.7700 - lr: 3.9727e-05
# Epoch 34/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5384 - accuracy: 0.7707
# Epoch 34: val_accuracy improved from 0.79133 to 0.79267, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 57ms/step - loss: 0.5384 - accuracy: 0.7707 - val_loss: 0.5190 - val_accuracy: 0.7927 - lr: 3.9331e-05
# Epoch 35/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5381 - accuracy: 0.7751
# Epoch 35: val_accuracy improved from 0.79267 to 0.80267, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 56ms/step - loss: 0.5387 - accuracy: 0.7747 - val_loss: 0.5101 - val_accuracy: 0.8027 - lr: 3.8940e-05
# Epoch 36/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5275 - accuracy: 0.7765
# Epoch 36: val_accuracy did not improve from 0.80267
# 115/115 [==============================] - 5s 47ms/step - loss: 0.5280 - accuracy: 0.7761 - val_loss: 0.5264 - val_accuracy: 0.7800 - lr: 3.8553e-05
# Epoch 37/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5285 - accuracy: 0.7785
# Epoch 37: val_accuracy improved from 0.80267 to 0.80533, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 65ms/step - loss: 0.5289 - accuracy: 0.7787 - val_loss: 0.5101 - val_accuracy: 0.8053 - lr: 3.8169e-05
# Epoch 38/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5192 - accuracy: 0.7855
# Epoch 38: val_accuracy did not improve from 0.80533
# 115/115 [==============================] - 5s 46ms/step - loss: 0.5190 - accuracy: 0.7858 - val_loss: 0.5032 - val_accuracy: 0.8053 - lr: 3.7789e-05
# Epoch 39/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5151 - accuracy: 0.7869
# Epoch 39: val_accuracy improved from 0.80533 to 0.80733, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 60ms/step - loss: 0.5151 - accuracy: 0.7871 - val_loss: 0.4949 - val_accuracy: 0.8073 - lr: 3.7413e-05
# Epoch 40/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5050 - accuracy: 0.7929
# Epoch 40: val_accuracy did not improve from 0.80733
# 115/115 [==============================] - 5s 47ms/step - loss: 0.5047 - accuracy: 0.7929 - val_loss: 0.4929 - val_accuracy: 0.8053 - lr: 3.7041e-05
# Epoch 41/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5085 - accuracy: 0.7887
# Epoch 41: val_accuracy did not improve from 0.80733
# 115/115 [==============================] - 5s 46ms/step - loss: 0.5085 - accuracy: 0.7887 - val_loss: 0.5464 - val_accuracy: 0.7840 - lr: 3.6672e-05
# Epoch 42/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5145 - accuracy: 0.7845
# Epoch 42: val_accuracy improved from 0.80733 to 0.81133, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 60ms/step - loss: 0.5145 - accuracy: 0.7845 - val_loss: 0.4845 - val_accuracy: 0.8113 - lr: 3.6307e-05
# Epoch 43/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.7956
# Epoch 43: val_accuracy did not improve from 0.81133
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4968 - accuracy: 0.7956 - val_loss: 0.5009 - val_accuracy: 0.7980 - lr: 3.5946e-05
# Epoch 44/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4996 - accuracy: 0.7942
# Epoch 44: val_accuracy improved from 0.81133 to 0.81667, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 60ms/step - loss: 0.4996 - accuracy: 0.7942 - val_loss: 0.4730 - val_accuracy: 0.8167 - lr: 3.5589e-05
# Epoch 45/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4897 - accuracy: 0.7998
# Epoch 45: val_accuracy did not improve from 0.81667
# 115/115 [==============================] - 5s 45ms/step - loss: 0.4897 - accuracy: 0.7998 - val_loss: 0.4863 - val_accuracy: 0.8093 - lr: 3.5234e-05
# Epoch 46/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4849 - accuracy: 0.7988
# Epoch 46: val_accuracy did not improve from 0.81667
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4849 - accuracy: 0.7988 - val_loss: 0.4992 - val_accuracy: 0.8093 - lr: 3.4884e-05
# Epoch 47/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.7934
# Epoch 47: val_accuracy did not improve from 0.81667
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4976 - accuracy: 0.7934 - val_loss: 0.4982 - val_accuracy: 0.8040 - lr: 3.4537e-05
# Epoch 48/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4811 - accuracy: 0.8028
# Epoch 48: val_accuracy did not improve from 0.81667
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4811 - accuracy: 0.8028 - val_loss: 0.5152 - val_accuracy: 0.8000 - lr: 3.4193e-05
# Epoch 49/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4808 - accuracy: 0.8039
# Epoch 49: val_accuracy improved from 0.81667 to 0.82533, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 60ms/step - loss: 0.4808 - accuracy: 0.8039 - val_loss: 0.4557 - val_accuracy: 0.8253 - lr: 3.3853e-05
# Epoch 50/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4814 - accuracy: 0.7999
# Epoch 50: val_accuracy did not improve from 0.82533
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4814 - accuracy: 0.7999 - val_loss: 0.5048 - val_accuracy: 0.7913 - lr: 3.3516e-05
# Epoch 51/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4713 - accuracy: 0.8057
# Epoch 51: val_accuracy did not improve from 0.82533
# 115/115 [==============================] - 5s 47ms/step - loss: 0.4715 - accuracy: 0.8058 - val_loss: 0.4608 - val_accuracy: 0.8207 - lr: 3.3183e-05
# Epoch 52/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4664 - accuracy: 0.8111
# Epoch 52: val_accuracy did not improve from 0.82533
# 115/115 [==============================] - 5s 45ms/step - loss: 0.4664 - accuracy: 0.8109 - val_loss: 0.4578 - val_accuracy: 0.8213 - lr: 3.2852e-05
# Epoch 53/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4625 - accuracy: 0.8109
# Epoch 53: val_accuracy did not improve from 0.82533
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4625 - accuracy: 0.8109 - val_loss: 0.4658 - val_accuracy: 0.8173 - lr: 3.2525e-05
# Epoch 54/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4638 - accuracy: 0.8093
# Epoch 54: val_accuracy did not improve from 0.82533
# 115/115 [==============================] - 5s 47ms/step - loss: 0.4634 - accuracy: 0.8093 - val_loss: 0.4592 - val_accuracy: 0.8120 - lr: 3.2202e-05
# Epoch 55/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4666 - accuracy: 0.8077
# Epoch 55: val_accuracy improved from 0.82533 to 0.83200, saving model to /content/checkpoint
# 115/115 [==============================] - 8s 68ms/step - loss: 0.4666 - accuracy: 0.8077 - val_loss: 0.4391 - val_accuracy: 0.8320 - lr: 3.1881e-05
# Epoch 56/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4519 - accuracy: 0.8177
# Epoch 56: val_accuracy did not improve from 0.83200
# 115/115 [==============================] - 5s 48ms/step - loss: 0.4519 - accuracy: 0.8177 - val_loss: 0.4382 - val_accuracy: 0.8307 - lr: 3.1564e-05
# Epoch 57/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4526 - accuracy: 0.8151
# Epoch 57: val_accuracy improved from 0.83200 to 0.83467, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 56ms/step - loss: 0.4526 - accuracy: 0.8151 - val_loss: 0.4320 - val_accuracy: 0.8347 - lr: 3.1250e-05
# Epoch 58/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4518 - accuracy: 0.8177
# Epoch 58: val_accuracy did not improve from 0.83467
# 115/115 [==============================] - 5s 47ms/step - loss: 0.4518 - accuracy: 0.8177 - val_loss: 0.4790 - val_accuracy: 0.8213 - lr: 3.0939e-05
# Epoch 59/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4488 - accuracy: 0.8192
# Epoch 59: val_accuracy did not improve from 0.83467
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4479 - accuracy: 0.8198 - val_loss: 0.4657 - val_accuracy: 0.8047 - lr: 3.0631e-05
# Epoch 60/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4513 - accuracy: 0.8160
# Epoch 60: val_accuracy did not improve from 0.83467
# 115/115 [==============================] - 5s 47ms/step - loss: 0.4513 - accuracy: 0.8160 - val_loss: 0.4289 - val_accuracy: 0.8340 - lr: 3.0327e-05
# Epoch 61/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4402 - accuracy: 0.8234
# Epoch 61: val_accuracy improved from 0.83467 to 0.83667, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.4402 - accuracy: 0.8234 - val_loss: 0.4199 - val_accuracy: 0.8367 - lr: 3.0025e-05
# Epoch 62/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4303 - accuracy: 0.8260
# Epoch 62: val_accuracy improved from 0.83667 to 0.84267, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 57ms/step - loss: 0.4303 - accuracy: 0.8260 - val_loss: 0.4140 - val_accuracy: 0.8427 - lr: 2.9726e-05
# Epoch 63/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4294 - accuracy: 0.8274
# Epoch 63: val_accuracy did not improve from 0.84267
# 115/115 [==============================] - 5s 47ms/step - loss: 0.4294 - accuracy: 0.8275 - val_loss: 0.4239 - val_accuracy: 0.8347 - lr: 2.9430e-05
# Epoch 64/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.8240
# Epoch 64: val_accuracy did not improve from 0.84267
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4378 - accuracy: 0.8240 - val_loss: 0.4172 - val_accuracy: 0.8393 - lr: 2.9137e-05
# Epoch 65/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4199 - accuracy: 0.8298
# Epoch 65: val_accuracy improved from 0.84267 to 0.84533, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 59ms/step - loss: 0.4199 - accuracy: 0.8298 - val_loss: 0.4137 - val_accuracy: 0.8453 - lr: 2.8847e-05
# Epoch 66/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4263 - accuracy: 0.8300
# Epoch 66: val_accuracy improved from 0.84533 to 0.84867, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 58ms/step - loss: 0.4263 - accuracy: 0.8300 - val_loss: 0.4084 - val_accuracy: 0.8487 - lr: 2.8560e-05
# Epoch 67/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4223 - accuracy: 0.8283
# Epoch 67: val_accuracy did not improve from 0.84867
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4223 - accuracy: 0.8283 - val_loss: 0.4812 - val_accuracy: 0.7947 - lr: 2.8276e-05
# Epoch 68/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4317 - accuracy: 0.8251
# Epoch 68: val_accuracy did not improve from 0.84867
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4317 - accuracy: 0.8251 - val_loss: 0.3985 - val_accuracy: 0.8467 - lr: 2.7995e-05
# Epoch 69/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4173 - accuracy: 0.8335
# Epoch 69: val_accuracy did not improve from 0.84867
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4167 - accuracy: 0.8340 - val_loss: 0.4005 - val_accuracy: 0.8433 - lr: 2.7716e-05
# Epoch 70/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4205 - accuracy: 0.8341
# Epoch 70: val_accuracy did not improve from 0.84867
# 115/115 [==============================] - 5s 47ms/step - loss: 0.4205 - accuracy: 0.8341 - val_loss: 0.4088 - val_accuracy: 0.8433 - lr: 2.7441e-05
# Epoch 71/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.8381
# Epoch 71: val_accuracy did not improve from 0.84867
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4060 - accuracy: 0.8381 - val_loss: 0.4187 - val_accuracy: 0.8373 - lr: 2.7168e-05
# Epoch 72/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4145 - accuracy: 0.8354
# Epoch 72: val_accuracy improved from 0.84867 to 0.85200, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 56ms/step - loss: 0.4145 - accuracy: 0.8354 - val_loss: 0.3891 - val_accuracy: 0.8520 - lr: 2.6897e-05
# Epoch 73/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4050 - accuracy: 0.8381
# Epoch 73: val_accuracy did not improve from 0.85200
# 115/115 [==============================] - 5s 46ms/step - loss: 0.4050 - accuracy: 0.8381 - val_loss: 0.3911 - val_accuracy: 0.8493 - lr: 2.6630e-05
# Epoch 74/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4052 - accuracy: 0.8384
# Epoch 74: val_accuracy did not improve from 0.85200
# 115/115 [==============================] - 5s 47ms/step - loss: 0.4052 - accuracy: 0.8384 - val_loss: 0.3962 - val_accuracy: 0.8467 - lr: 2.6365e-05
# Epoch 75/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4038 - accuracy: 0.8406
# Epoch 75: val_accuracy improved from 0.85200 to 0.85267, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 57ms/step - loss: 0.4034 - accuracy: 0.8406 - val_loss: 0.3867 - val_accuracy: 0.8527 - lr: 2.6102e-05
# Epoch 76/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4046 - accuracy: 0.8402
# Epoch 76: val_accuracy improved from 0.85267 to 0.85400, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.4033 - accuracy: 0.8407 - val_loss: 0.3851 - val_accuracy: 0.8540 - lr: 2.5843e-05
# Epoch 77/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.8436
# Epoch 77: val_accuracy did not improve from 0.85400
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3965 - accuracy: 0.8436 - val_loss: 0.3970 - val_accuracy: 0.8440 - lr: 2.5585e-05
# Epoch 78/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3915 - accuracy: 0.8467
# Epoch 78: val_accuracy did not improve from 0.85400
# 115/115 [==============================] - 5s 47ms/step - loss: 0.3915 - accuracy: 0.8467 - val_loss: 0.3811 - val_accuracy: 0.8487 - lr: 2.5331e-05
# Epoch 79/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3911 - accuracy: 0.8478
# Epoch 79: val_accuracy improved from 0.85400 to 0.86067, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 60ms/step - loss: 0.3911 - accuracy: 0.8478 - val_loss: 0.3774 - val_accuracy: 0.8607 - lr: 2.5079e-05
# Epoch 80/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3903 - accuracy: 0.8468
# Epoch 80: val_accuracy did not improve from 0.86067
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3907 - accuracy: 0.8463 - val_loss: 0.3740 - val_accuracy: 0.8560 - lr: 2.4829e-05
# Epoch 81/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3821 - accuracy: 0.8492
# Epoch 81: val_accuracy did not improve from 0.86067
# 115/115 [==============================] - 5s 47ms/step - loss: 0.3821 - accuracy: 0.8492 - val_loss: 0.3909 - val_accuracy: 0.8480 - lr: 2.4582e-05
# Epoch 82/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3839 - accuracy: 0.8479
# Epoch 82: val_accuracy did not improve from 0.86067
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3839 - accuracy: 0.8479 - val_loss: 0.4194 - val_accuracy: 0.8213 - lr: 2.4338e-05
# Epoch 83/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3809 - accuracy: 0.8507
# Epoch 83: val_accuracy did not improve from 0.86067
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3809 - accuracy: 0.8507 - val_loss: 0.3677 - val_accuracy: 0.8567 - lr: 2.4095e-05
# Epoch 84/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3818 - accuracy: 0.8501
# Epoch 84: val_accuracy improved from 0.86067 to 0.86467, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.3825 - accuracy: 0.8499 - val_loss: 0.3643 - val_accuracy: 0.8647 - lr: 2.3856e-05
# Epoch 85/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3821 - accuracy: 0.8486
# Epoch 85: val_accuracy did not improve from 0.86467
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3821 - accuracy: 0.8486 - val_loss: 0.3650 - val_accuracy: 0.8627 - lr: 2.3618e-05
# Epoch 86/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3731 - accuracy: 0.8550
# Epoch 86: val_accuracy improved from 0.86467 to 0.86600, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.3731 - accuracy: 0.8550 - val_loss: 0.3630 - val_accuracy: 0.8660 - lr: 2.3383e-05
# Epoch 87/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3743 - accuracy: 0.8520
# Epoch 87: val_accuracy did not improve from 0.86600
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3739 - accuracy: 0.8519 - val_loss: 0.3792 - val_accuracy: 0.8493 - lr: 2.3151e-05
# Epoch 88/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3765 - accuracy: 0.8494
# Epoch 88: val_accuracy did not improve from 0.86600
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3765 - accuracy: 0.8494 - val_loss: 0.3611 - val_accuracy: 0.8627 - lr: 2.2920e-05
# Epoch 89/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3695 - accuracy: 0.8561
# Epoch 89: val_accuracy did not improve from 0.86600
# 115/115 [==============================] - 5s 48ms/step - loss: 0.3698 - accuracy: 0.8558 - val_loss: 0.3762 - val_accuracy: 0.8600 - lr: 2.2692e-05
# Epoch 90/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8564
# Epoch 90: val_accuracy did not improve from 0.86600
# 115/115 [==============================] - 5s 47ms/step - loss: 0.3684 - accuracy: 0.8564 - val_loss: 0.3824 - val_accuracy: 0.8440 - lr: 2.2466e-05
# Epoch 91/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3713 - accuracy: 0.8544
# Epoch 91: val_accuracy did not improve from 0.86600
# 115/115 [==============================] - 6s 54ms/step - loss: 0.3713 - accuracy: 0.8544 - val_loss: 0.3665 - val_accuracy: 0.8607 - lr: 2.2243e-05
# Epoch 92/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3707 - accuracy: 0.8564
# Epoch 92: val_accuracy did not improve from 0.86600
# 115/115 [==============================] - 6s 48ms/step - loss: 0.3707 - accuracy: 0.8564 - val_loss: 0.3568 - val_accuracy: 0.8613 - lr: 2.2022e-05
# Epoch 93/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3617 - accuracy: 0.8595
# Epoch 93: val_accuracy did not improve from 0.86600
# 115/115 [==============================] - 5s 47ms/step - loss: 0.3617 - accuracy: 0.8595 - val_loss: 0.4099 - val_accuracy: 0.8287 - lr: 2.1802e-05
# Epoch 94/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3633 - accuracy: 0.8585
# Epoch 94: val_accuracy improved from 0.86600 to 0.87067, saving model to /content/checkpoint
# 115/115 [==============================] - 6s 56ms/step - loss: 0.3628 - accuracy: 0.8588 - val_loss: 0.3472 - val_accuracy: 0.8707 - lr: 2.1586e-05
# Epoch 95/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3679 - accuracy: 0.8564
# Epoch 95: val_accuracy did not improve from 0.87067
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3678 - accuracy: 0.8563 - val_loss: 0.4126 - val_accuracy: 0.8307 - lr: 2.1371e-05
# Epoch 96/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3584 - accuracy: 0.8628
# Epoch 96: val_accuracy did not improve from 0.87067
# 115/115 [==============================] - 5s 46ms/step - loss: 0.3584 - accuracy: 0.8628 - val_loss: 0.3496 - val_accuracy: 0.8673 - lr: 2.1158e-05
# Epoch 97/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.8601
# Epoch 97: val_accuracy improved from 0.87067 to 0.87533, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.3627 - accuracy: 0.8601 - val_loss: 0.3480 - val_accuracy: 0.8753 - lr: 2.0948e-05
# Epoch 98/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3575 - accuracy: 0.8621
# Epoch 98: val_accuracy did not improve from 0.87533
# 115/115 [==============================] - 7s 58ms/step - loss: 0.3571 - accuracy: 0.8625 - val_loss: 0.3580 - val_accuracy: 0.8700 - lr: 2.0739e-05
# Epoch 99/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3551 - accuracy: 0.8642
# Epoch 99: val_accuracy improved from 0.87533 to 0.87733, saving model to /content/checkpoint
# 115/115 [==============================] - 7s 61ms/step - loss: 0.3551 - accuracy: 0.8642 - val_loss: 0.3403 - val_accuracy: 0.8773 - lr: 2.0533e-05
# Epoch 100/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3511 - accuracy: 0.8659
# Epoch 100: val_accuracy did not improve from 0.87733
# 115/115 [==============================] - 6s 54ms/step - loss: 0.3511 - accuracy: 0.8659 - val_loss: 0.3441 - val_accuracy: 0.8707 - lr: 2.0328e-05

# %% [markdown]
# # Model Evaluation
#
# **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the models performance.**

# %%
# CodeGrade Tag Ex4a
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Validation and Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Validation and Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Show the plots
plt.show()

# %% [markdown]
# **Load the best weights from your model checkpoint, and create plots demonstrating the classification perfomnce for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %%
# CodeGrade Tag Ex4b

class_names = {0: 'cat', 1: 'dog', 2: 'wild'}
# Load the model
model.load_weights(checkpoint_filepath)

def predict_and_plot(dataset, class_names, model, num_images=6, rows=2, cols=3):
    fig, axes = plt.subplots(rows, cols, figsize=(6, 4 * rows))

    for k, (images, labels) in enumerate(dataset.take(num_images)):
        predictions = model.predict(images)

        i, j = divmod(k, cols)
        image = (images[j].numpy() * 255).astype(np.uint8)

        # Get true and predicted labels
        true_label = class_names[labels[j].numpy()]
        predicted_label = class_names[np.argmax(predictions[j])]

        # Set color based on whether the prediction is correct or not
        text_color = 'green' if true_label == predicted_label else 'red'

        # Plot the image
        ax = axes[i, j]
        ax.imshow(image)
        ax.set_title(f"True: {true_label}\nPredicted: {predicted_label}", color=text_color)
        ax.axis('off')

    # Adjust layout for better spacing
    plt.subplots_adjust(wspace=0.5, hspace=0.3)

    plt.tight_layout()
    plt.show()

# Predict and plot 6 images from the validation dataset in a 2x3 grid using the loaded model
predict_and_plot(valid_ds, class_names, model, num_images=6, rows=2, cols=3)


predictions = model.predict(valid_ds)
true_labels = [label.numpy() for _, label in valid_ds]
class_labels = list(label_dict.keys())

plt.figure(figsize=(12, 8))

for i, class_label in enumerate(class_labels):
    plt.subplot(1, 3, i + 1)

    counts = {
        'True +ves': sum((predictions.argmax(axis=1) == i) & (true_labels == i)),
        'True -ves': sum((predictions.argmax(axis=1) != i) & (true_labels != i)),
        'False +ves': sum((predictions.argmax(axis=1) == i) & (true_labels != i)),
        'False -ves': sum((predictions.argmax(axis=1) != i) & (true_labels == i)),
    }

    plt.bar(counts.keys(), counts.values())
    plt.title(f'Class: {class_label}')
    plt.ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 6ms/step
# 12/12 [==============================] - 0s 15ms/step
